# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.offline_inf.src import Inference, InfConfig
import cv2

# %%
image_path = "testimg.jpg"

# %%
config = InfConfig(
    model_path="data/model/Mobilenet-28-3-256-256.onnx",
    input_layer_name="input",
)
inf = Inference(config=config, inference_only=True)

image = cv2.imread(image_path)
processed_patches = inf.preprocess(image)

predictions = inf.run_inference(processed_patches)
predictions.shape, predictions
# Out:
# ((28,),
#  array([2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2], dtype=int32))
